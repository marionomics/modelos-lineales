# %%
# Cargamos los módulos
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
diccionario ={
    'female': np.random.binomial(1,0.5, 10000),
    'ability': np.random.normal(size=10000)
}

# %%
df = pd.DataFrame(diccionario)
df['discrimination'] = df.female.copy()
df['occupation'] = 1 + df['ability']*2 + df['female']*0 - df['discrimination'] * 2 + np.random.normal(size=10000)
df['wage'] = 1 - df['discrimination'] + df['occupation'] + df['ability'] + np.random.normal(size=10000)
df.head()
# Out:
#    female   ability  discrimination  occupation      wage
# 0       0 -0.547747               0   -0.005336  1.061173
# 1       0 -0.943300               0   -0.498001 -1.371667
# 2       0 -0.798733               0   -0.315066  1.145345
# 3       0  1.608723               0    4.820205  7.201098
# 4       0  1.259751               0    3.396563  5.540877

# %%
modelo1 = sm.OLS.from_formula('wage ~ female', data = df)
modelo2 = sm.OLS.from_formula('wage ~ female + occupation', data = df)
modelo3 = sm.OLS.from_formula('wage ~ female + occupation + ability', data = df)

# %%
modelo1.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.172
# Method:                 Least Squares   F-statistic:                     2077.
# Date:                Sat, 04 Jun 2022   Prob (F-statistic):               0.00
# Time:                        10:56:22   Log-Likelihood:                -26043.
# No. Observations:               10000   AIC:                         5.209e+04
# Df Residuals:                    9998   BIC:                         5.210e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9279      0.046     41.887      0.000       1.838       2.018
# female        -2.9826      0.065    -45.574      0.000      -3.111      -2.854
# ==============================================================================
# Omnibus:                        3.411   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.182   Jarque-Bera (JB):                3.440
# Skew:                          -0.041   Prob(JB):                        0.179
# Kurtosis:                       2.961   Cond. No.                         2.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
modelo2.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.907
# Model:                            OLS   Adj. R-squared:                  0.907
# Method:                 Least Squares   F-statistic:                 4.894e+04
# Date:                Sat, 04 Jun 2022   Prob (F-statistic):               0.00
# Time:                        10:58:06   Log-Likelihood:                -15093.
# No. Observations:               10000   AIC:                         3.019e+04
# Df Residuals:                    9997   BIC:                         3.021e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6168      0.016     38.343      0.000       0.585       0.648
# female        -0.2387      0.024     -9.961      0.000      -0.286      -0.192
# occupation     1.3969      0.005    281.644      0.000       1.387       1.407
# ==============================================================================
# Omnibus:                        3.262   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.196   Jarque-Bera (JB):                3.286
# Skew:                           0.038   Prob(JB):                        0.193
# Kurtosis:                       2.954   Cond. No.                         6.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
modelo3.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   wage   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                 4.052e+04
# Date:                Sat, 04 Jun 2022   Prob (F-statistic):               0.00
# Time:                        10:59:41   Log-Likelihood:                -14101.
# No. Observations:               10000   AIC:                         2.821e+04
# Df Residuals:                    9996   BIC:                         2.824e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0262      0.017     60.407      0.000       0.993       1.060
# female        -1.0585      0.028    -37.967      0.000      -1.113      -1.004
# occupation     0.9826      0.010     99.046      0.000       0.963       1.002
# ability        1.0365      0.022     46.844      0.000       0.993       1.080
# ==============================================================================
# Omnibus:                        5.246   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.073   Jarque-Bera (JB):                5.243
# Skew:                           0.048   Prob(JB):                       0.0727
# Kurtosis:                       2.941   Cond. No.                         9.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
